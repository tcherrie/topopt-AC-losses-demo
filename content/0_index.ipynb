# %% [markdown]
# # Parametric and topology optimization of conductors in electrical machines
# ___
# ## Notebooks
#
# - [1_reference_simulation](1_reference_simulation.ipynb)
# - [2_taylor_tests](2_taylor_tests.ipynb)
# - [3_single_material_optimization](3_single_material_optimization.ipynb)
# - [4_multi_material_optimization](4_multi_material_optimization.ipynb)
# - [5_topology_optimization](5_topology_optimization.ipynb)
# - [6_slot_model](6_slot_model.ipynb)
# - [7_topology_optimization_slot](7_topology_optimization_slot.ipynb)

# %% [markdown]
# ___
# ## References using this repository
#
# - [ICEM2026](https://icem2026.ubi.pt/)
# > Cherrière T., Pons A., Krebs G., Mercier A., Benmamas L. & Küttler S.  (2026)
# > ***Reducing AC losses in Halbach electrical machines with density topology optimization of winding***
# > *International Conference on Electrical Machines (ICEM 2026), Madeiras, September 2026*
# > paper DOI: *to be published*
# > Code DOI:  [![DOI](https://zenodo.org/badge/1240891081.svg)](https://doi.org/10.5281/zenodo.20457486)
#
# - [EurOpt 2026](https://www.jku.at/en/institute-of-business-analytics-and-technology-transformation/conference-europt-2026/)
# > Cherrière T.  (2026)
# > ***Mitigating AC losses in electrical machines with topology optimization***
# > *23rd EUROPT Conference on Advances in Continuous Optimization (EUROPT 2026), Linz, July 2026*
# > (no proceedings)
